# %%
import csv
import matplotlib.pyplot as plt 
from math import log, sqrt

def loadDataMoreInputs(fileName):
    data = []
    dataNames = []
    with open(fileName) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for row in csv_reader:
            if line_count == 0:
                dataNames = row
            else:
                data.append(row)
            line_count += 1
    return dataNames, data

def extractFeature(allData, names, featureName):
    pos = names.index(featureName)
    return [data[pos] for data in allData]

def plotDataHistogram(x, variableName):
    n, bins, patches = plt.hist(x, 20)
    plt.title('Histogram of ' + variableName)
    plt.show()
    
dataNames,data=loadDataMoreInputs("surveyDataSience.csv")

print("Numarul de respondenti: ",len(extractFeature(data,dataNames,"Q1"))-1)

print("Numarul coloanelor: ",len(data[0]))

#for i in range (len(data[0])):
    #print(type(data[0][i]))

nr=0
for i in data:
    ok=1
    for j in range(7):
        if  i[j]=="":
            ok=0
            break
    if ok==1:
        nr+=1

print("Numar respondenti complet: ", nr)

medie=0
n=25973
durata=extractFeature(data,dataNames,"Q4")
gen=extractFeature(data,dataNames,"Q2")
for d in durata:
    if d=='Bachelor’s degree':
        medie+=3
    elif d=='Master’s degree':
        medie+=5
    elif d=='Doctoral degree':
        medie+=8
    else :
        medie+=0
        
print("Medie durata: ",medie/n)

nr=0
suma=0
for i in range(len(durata)):
    if gen[i]=='Woman':
        nr+=1
        if durata[i]=='Bachelor’s degree':
            suma+=3
        elif durata[i]=='Master’s degree':
            suma+=5
        elif durata[i]=='Doctoral degree':
            suma+=8
        else :
            suma+=0

print("Medie femei: ",suma/nr)

nr=0
for i in data:
    if i[2]=='Woman':
        ok=1
        for j in range(7):
            if  i[j]=="":
                ok=0
                break
        if ok==1:
            nr+=1

nr=0
for i in data:
    if i[2]=='Woman' and i[7]=='Python':
            nr+=1

print("Femei cu date complete: ",nr)

v=[0]*11

for i in data:
    if i[2]=='Woman' and i[7]=='Python':
        if i[1]=='18-21':
            v[0]+=1
        elif i[1]=='22-24':
            v[1]+=1
        elif i[1]=='25-29':
            v[2]+=1
        elif i[1]=='30-34':
            v[3]+=1
        elif i[1]=='35-39':
            v[4]+=1
        elif i[1]=='40-44':
            v[5]+=1
        elif i[1]=='45-49':
            v[6]+=1
        elif i[1]=='50-54':
            v[7]+=1
        elif i[1]=='55-59':
            v[8]+=1
        elif i[1]=='60-69':
            v[9]+=1
        else:
            v[10]+=1

maxi=0

for i in range(len(v)):
    if v[i]>v[maxi]:
        maxi=i

if maxi==0:
    print("Intervalul de varsta: 18-21")
elif maxi==1:
    print("Intervalul de varsta: 22-24")
elif maxi==2:
    print("Intervalul de varsta: 25-29")
elif maxi==3:
    print("Intervalul de varsta: 30-34")
elif maxi==4:
    print("Intervalul de varsta: 35-39")
elif maxi==5:
    print("Intervalul de varsta: 40-44")
elif maxi==6:
    print("Intervalul de varsta: 45-49")
elif maxi==7:
    print("Intervalul de varsta: 50-54")
elif maxi==8:
    print("Intervalul de varsta: 55-59")
elif maxi==9:
    print("Intervalul de varsta: 60-69")
else:
    print("Intervalul de varsta: 70+")


v=[0]*11

for i in data:
    if i[2]=='Woman' and i[11]=='C++':
        if i[1]=='18-21':
            v[0]+=1
        elif i[1]=='22-24':
            v[1]+=1
        elif i[1]=='25-29':
            v[2]+=1
        elif i[1]=='30-34':
            v[3]+=1
        elif i[1]=='35-39':
            v[4]+=1
        elif i[1]=='40-44':
            v[5]+=1
        elif i[1]=='45-49':
            v[6]+=1
        elif i[1]=='50-54':
            v[7]+=1
        elif i[1]=='55-59':
            v[8]+=1
        elif i[1]=='60-69':
            v[9]+=1
        else:
            v[10]+=1

maxi=0

for i in range(len(v)):
    if v[i]>v[maxi]:
        maxi=i

if maxi==0:
    print("Intervalul de varsta: 18-21")
elif maxi==1:
    print("Intervalul de varsta: 22-24")
elif maxi==2:
    print("Intervalul de varsta: 25-29")
elif maxi==3:
    print("Intervalul de varsta: 30-34")
elif maxi==4:
    print("Intervalul de varsta: 35-39")
elif maxi==5:
    print("Intervalul de varsta: 40-44")
elif maxi==6:
    print("Intervalul de varsta: 45-49")
elif maxi==7:
    print("Intervalul de varsta: 50-54")
elif maxi==8:
    print("Intervalul de varsta: 55-59")
elif maxi==9:
    print("Intervalul de varsta: 60-69")
else:
    print("Intervalul de varsta: 70+")
# Out:
# Numarul de respondenti:  25973
# Numarul coloanelor:  369
# Numar respondenti complet:  25974
# Medie durata:  3.9556847495476073
# Medie femei:  4.048875255623722
# Femei cu date complete:  3877
# Intervalul de varsta: 18-21
# Intervalul de varsta: 18-21

# %%
domeniul de valori posibile si valorile extreme pentru fiecare atribut/proprietate (feature).
In cazul proprietatilor nenumerice, cate valori posibile are fiecare astfel de proprietate

# %%
import csv
import matplotlib.pyplot as plt 
from math import log, sqrt

def loadDataMoreInputs(fileName):
    data = []
    dataNames = []
    with open(fileName) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for row in csv_reader:
            if line_count == 0:
                dataNames = row
            else:
                data.append(row)
            line_count += 1
    return dataNames, data

def extractFeature(allData, names, featureName):
    pos = names.index(featureName)
    return [data[pos] for data in allData]

def plotDataHistogram(x, variableName):
    n, bins, patches = plt.hist(x, 20)
    plt.title('Histogram of ' + variableName)
    plt.show()
    
dataNames,data=loadDataMoreInputs("surveyDataSience.csv")


def has_numbers(inputString):
    return any(char.isdigit() for char in inputString)

def convert_to_numeric(value):
    
    if value.startswith('<'):
        return 0
    val2=''
    for i in range(len(value)):
        if value[i].isdigit() or value[i]==',':
            if value[i]==',':
                val2+=''
            else:
                val2+=value[i]
        elif i!=0:
            break
    if val2=='':
        return 0
    return float(val2)


for i in range(1,len(data[0])):
    dat=extractFeature(data,dataNames,dataNames[i])
    print("Feature ",i)
    print("Domeniu: ",list(set(dat[1:])))
    print("Nr valori: ",len(list(set(dat[1:]))))
    if has_numbers(dat[1]):
        numeric_data = []
        for d in list(set(dat)): 
            if has_numbers(d):
                numeric_value = convert_to_numeric(d)
                if numeric_value!=-12.2:
                    numeric_data.append(numeric_value)
       
        if numeric_data!=[]:
            print("Minim: ",min(numeric_data))
            print("Maxim: ",max(numeric_data))
# Out:
# Feature  1
# Domeniu:  ['45-49', '30-34', '50-54', '70+', '35-39', '22-24', '25-29', '60-69', '18-21', '40-44', '55-59']
# Nr valori:  11
# Minim:  18.0
# Maxim:  70.0
# Feature  2
# Domeniu:  ['Prefer not to say', 'Woman', 'Man', 'Nonbinary', 'Prefer to self-describe']
# Nr valori:  5
# Feature  3
# ...

# %%
transformati informatiile despre vechimea in programare in numar de ani (folositi in locul intervalului, mijlocul 
acestuia) si apoi calculati momentele de ordin 1 si 2 pentru aceasta variabila (minim, maxim, media, deviatia 
standard, mediana). Ce se poate spune despre aceasta variabila?

# %%
import csv
import matplotlib.pyplot as plt 
from math import log, sqrt
import numpy as np

def loadDataMoreInputs(fileName):
    data = []
    dataNames = []
    with open(fileName) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for row in csv_reader:
            if line_count == 0:
                dataNames = row
            else:
                data.append(row)
            line_count += 1
    return dataNames, data

def extractFeature(allData, names, featureName):
    pos = names.index(featureName)
    return [data[pos] for data in allData]

def plotDataHistogram(x, variableName):
    n, bins, patches = plt.hist(x, 20)
    plt.title('Histogram of ' + variableName)
    plt.show()
    
dataNames,data=loadDataMoreInputs("surveyDataSience.csv")

vechimi=extractFeature(data,dataNames,"Q6")

def transformNr(interval):
    if interval == "< 1 years":
        return 0.5
    elif interval == "1-3 years":
        return 2
    elif interval == "3-5 years":
        return 4
    elif interval == "5-10 years":
        return 7.5
    elif interval == "10-20 years":
        return 15
    elif interval == "20+ years":
        return 20
    else:
        return None

years=[transformNr(interval) for interval in list(set(vechimi)) if transformNr(interval) is not None]

minim=np.min(years)
maxim=np.max(years)
media= np.mean(years)
deviatia= np.std(years)
mediana= np.median(years)

print("Minim: ",minim )
print("Maxim: ",maxim )
print("Medie: ",media)
print("Deviație standard: ",deviatia)
print("Mediana: ", mediana)
# Out:
# Minim:  0.5
# Maxim:  20.0
# Medie:  8.166666666666666
# Deviație standard:  7.086763875156433
# Mediana:  5.75

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt 
from math import log, sqrt
import numpy as np
import seaborn as sns


def loadDataMoreInputs(fileName):
    data = []
    dataNames = []
    with open(fileName) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for row in csv_reader:
            if line_count == 0:
                dataNames = row
            else:
                data.append(row)
            line_count += 1
    return dataNames, data

def extractFeature(allData, names, featureName):
    pos = names.index(featureName)
    return [data[pos] for data in allData]

def plotDataHistogram(x, variableName):
    n, bins, patches = plt.hist(x, 20)
    plt.title('Histogram of ' + variableName)
    plt.show()
    
dataNames,data=loadDataMoreInputs("surveyDataSience.csv")

dat=pd.read_csv("surveyDataSience.csv")

useri=dat[dat["Q7_Part_1"]=="Python"]

plt.figure(figsize=(10,6))
sns.countplot(data=useri,x="Q1",order=useri["Q1"].value_counts().index)
plt.xlabel("Categorie de varsta")
plt.ylabel("Numar de respondenti")
plt.show()

rouser=useri[useri["Q3"]=="Romania"]
plt.figure(figsize=(10,6))
sns.countplot(data=rouser,x="Q1",order=rouser["Q1"].value_counts().index)
plt.xlabel("Categorie de varsta")
plt.ylabel("Numar de respondenti")
plt.show()

fuseri=rouser[rouser["Q2"]=="Woman"]
plt.figure(figsize=(10,6))
sns.countplot(data=fuseri,x="Q1",order=fuseri["Q1"].value_counts().index)
plt.xlabel("Categorie de varsta")
plt.ylabel("Numar de respondenti")
plt.show()


def transformNr(interval):
    if interval == "< 1 years":
        return 0.5
    elif interval == "1-3 years":
        return 2
    elif interval == "3-5 years":
        return 4
    elif interval == "5-10 years":
        return 7.5
    elif interval == "10-20 years":
        return 15
    elif interval == "20+ years":
        return 20
    else:
        return None
dat["Years of Experience"]=dat["Q6"].apply(transformNr)
plt.figure(figsize=(10,6))
sns.boxplot(x=dat["Years of Experience"])
plt.xlabel("Vechime")
plt.show()

q1=dat["Years of Experience"].quantile(0.25)#valoarea care separa cele mai mici 25% din date
q3=dat["Years of Experience"].quantile(0.75)#valoarea care separa cele mai mari 25% din date
iqr=q3-q1
outliers=dat[(dat["Years of Experience"]<(q1-1.5*iqr))|(dat["Years of Experience"]>(q3+1.5*iqr))]
print(outliers[["Q2","Q6","Years of Experience"]])
# Out:
# /tmp/ipykernel_110/3641883284.py:34: DtypeWarning: Columns (0,18,32,49,56,69,88,100,107,113,139,184,195,201,202,253,266,278,283,285,286,287,288,289,290,291,292,301,322,339,347,355,367) have mixed types. Specify dtype option on import or set low_memory=False.
#   dat=pd.read_csv("surveyDataSience.csv")
#         Q2         Q6  Years of Experience
# 2      Man  20+ years                 20.0
# 4      Man  20+ years                 20.0
# 17     Man  20+ years                 20.0
# 24     Man  20+ years                 20.0
# 70     Man  20+ years                 20.0
# ...    ...        ...                  ...
# 25863  Man  20+ years                 20.0
# 25888  Man  20+ years                 20.0
# 25911  Man  20+ years                 20.0
# 25925  Man  20+ years                 20.0
# 25964  Man  20+ years                 20.0
#
# [1860 rows x 3 columns]

# %%
Se dau mai multe imagini (salvate in folder-ul "data/images"). Se cere:

sa se vizualizeze una din imagini
daca imaginile nu aceeasi dimensiune, sa se redimensioneze toate la 128 x 128 pixeli si sa se vizualizeze imaginile intr-un cadru tabelar.
sa se transforme imaginile in format gray-levels si sa se vizualizeze
sa se blureze o imagine si sa se afiseze in format "before-after"
sa se identifice muchiile intr-o imagine si sa se afiseze in format "before-after"

# %%
import matplotlib.pyplot as plt
from skimage import exposure, io,transform,color,feature
from skimage.feature import hog
import os
from skimage.filters import gaussian


crtDir =  os.getcwd()
filePath = os.path.join(crtDir,'Images', 'YOLO.jpg')
img = io.imread(filePath)


print("Afisarea unei imagini")
fig, ax = plt.subplots(1, 1)
ax.imshow(img, cmap=plt.cm.gray)
plt.show()

print("Afisare tabelara")
crtDir =  os.getcwd()
filePath = os.path.join(crtDir,'Images')
images=[]
for filename in os.listdir(filePath):
    if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith(".webp"):
        path=os.path.join(filePath,filename)
        img=io.imread(path)
        images.append(img)

resizedIm=[transform.resize(img,(128,128)) for img in images]
fig,ax=plt.subplots(3,4)
for i in range(len(resizedIm)):
    ax[i%3][i//3].imshow(resizedIm[i])
fig.show()

#img[..., :3] selecteaza primele trei canale RGB
#img.ndim==3 and img.shape[-1]>=3 modificam doar imaginile car eau macar 3 canale adica nu sunt alb negru
grayIm=[color.rgb2gray(img[..., :3]) if img.ndim==3 and img.shape[-1]>=3 else img for img in resizedIm]
fig2,ax2=plt.subplots(3,4)
for i in range(len(grayIm)):
    ax2[i%3][i//3].imshow(grayIm[i],cmap=plt.cm.gray)
fig2.show()


blurImg=gaussian(img,sigma=2,channel_axis=-1)
blurImg=np.clip(blurImg,0,1)
fig3,(ax3, ax4)=plt.subplots(1,2)
ax3.set_title("Before")
ax4.set_title("After")
ax3.imshow(img)
ax4.imshow(blurImg)
plt.show()

edges=feature.canny(color.rgb2gray(img),sigma=1)
fig4,(ax5, ax6)=plt.subplots(1,2)
ax5.set_title("Before")
ax6.set_title("After")
ax5.imshow(img)
ax6.imshow(edges)
plt.show()
# Out:
# Afisarea unei imagini
# Afisare tabelara
# Format gray levels

# %%
Se da un fisier care contine un text (format din mai multe propozitii) in limba romana - a se vedea fisierul ”data/texts.txt”. Se cere sa se determine si sa se vizualizeze:

numarul de propozitii din text;
numarul de cuvinte din text
numarul de cuvinte diferite din text
cel mai scurt si cel mai lung cuvant (cuvinte)
textul fara diacritice
sinonimele celui mai lung cuvant din text

# %%
#pip install nltk
"""import nltk
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')"""
# !pip install unidecode
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 1.2 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import nltk
import re
from unidecode import unidecode
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

filePath="texts.txt"
with open(filePath, "r", encoding="utf-8") as file:
    text=file.read()

prop=nltk.sent_tokenize(text, language='english')
nrprop=len(prop)
print("Numar propozitii: ", nrprop)

cuv=nltk.word_tokenize(text)
cuv=[c.lower() for c in cuv if c.isalpha()]
nrcuv=len(cuv)
print("Numar cuvinte: ", nrcuv)

cuvunic=set(cuv)
nrcuvunic=len(cuvunic)
print("Numar unice: ",nrcuvunic)

scurt=min(cuvunic,key=len)
lung=max(cuvunic,key=len)
print("Cel mai scurt: ",scurt)
print("Cel mai lung: ",lung)

faraDiacr=unidecode(text)
print("Fara diacritice: ")
print(faraDiacr)

sinonime=set()
lemmatizer = WordNetLemmatizer()
lung = re.sub(r'(.)\1+', r'\1', lung)
print(lung)
for s in wordnet.synsets(lung):
    for l in s.lemmas():
        sinonime.add(l.name())

print(sinonime)
# Out:
# Numar propozitii:  10
# Numar cuvinte:  158
# Numar unice:  90
# Cel mai scurt:  o
# Cel mai lung:  confiiiiiiiiiiiiiiiiiiiiiiiiiiiirm
# Fara diacritice:
# Mesaj de informare:
# Cursul si laboratoarele de Inteligenta Artificiala vor fi o
# provocare pentru toti. Suntem convinsi ca veti realiza proiecte
# foarte interesante. Va incurajam sa adresati intrebari atunci
# cand ceva nu e clar, atat in mod live, cat si folosind platforma
# Teams, canalul "general".
# Daca ati citit pana aici, va rugam sa lasati un mesaj pe canalul
# general cu textul "Confiiiiiiiiiiiiiiiiiiiiiiiiiiiirm ca am citit
# textul pentru problema 3 din lab2".
# --
# Mesaj de informare generat de ChatGPT:
# Stimati cursanti,
# Suntem incantati sa va avem in echipa noastra pentru Cursul si
# laboratoarele de Inteligenta Artificiala. Aceasta experienta va
# fi o adevarata provocare, dar suntem convinsi ca veti realiza
# proiecte extrem de interesante.
# Va incurajam sa fiti activi si sa adresati intrebari atunci cand
# ...

# %%
Sa se normalizeze informatiile de la problema 1 si 2 folosind diferite metode de normalizare astfel:

problema 1 - durata anilor de studii universitare, vechimea in programare
problema 2 - valorile pixelilor din imagini
problema 3 - numarul de aparitii a cuvintelor la nivelul unei propozitii.

# %%
import csv
import matplotlib.pyplot as plt 
from math import log, sqrt
import numpy as np

def loadDataMoreInputs(fileName):
    data = []
    dataNames = []
    with open(fileName) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for row in csv_reader:
            if line_count == 0:
                dataNames = row
            else:
                data.append(row)
            line_count += 1
    return dataNames, data

def extractFeature(allData, names, featureName):
    pos = names.index(featureName)
    return [data[pos] for data in allData]

def plotDataHistogram(x, variableName):
    n, bins, patches = plt.hist(x, 20)
    plt.title('Histogram of ' + variableName)
    plt.show()
    
dataNames,data=loadDataMoreInputs("surveyDataSience.csv")

vechimi=extractFeature(data,dataNames,"Q6")

def transformNr(interval):
    if interval == "< 1 years":
        return 0.5
    elif interval == "1-3 years":
        return 2
    elif interval == "3-5 years":
        return 4
    elif interval == "5-10 years":
        return 7.5
    elif interval == "10-20 years":
        return 15
    elif interval == "20+ years":
        return 20
    else:
        return None

years=[transformNr(interval) for interval in list(set(vechimi)) if transformNr(interval) is not None]

minim=np.min(years)
maxim=np.max(years)
media= np.mean(years)
deviatia= np.std(years)
mediana= np.median(years)

#Z NORMALISATION
yearsZ=[(p-media)/deviatia for p in years]


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
ax1.hist(years, 20)
ax1.set_title('years histo')
ax2.hist(yearsZ, 20)
ax2.set_title('z-score years histo')
plt.show()


#MIN MAX NORMALIZATION
medie=0
n=25973
durata=extractFeature(data,dataNames,"Q4")
durataNr=[]
for d in durata:
    if d=='Bachelor’s degree':
        medie+=3
        durataNr.append(3)
    elif d=='Master’s degree':
        medie+=5
        durataNr.append(5)
    elif d=='Doctoral degree':
        medie+=8
        durataNr.append(8)
    else :
        medie+=0
        durataNr.append(0)

durataMinMax=[(d-0)/8 for d in durataNr]
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
ax1.hist(durataNr, 20)
ax1.set_title('durata histo')
ax2.hist(durataMinMax, 20)
ax2.set_title('[0,1] durata histo')
plt.show()



#PENTRU 2 FEATURE-uri
years=[transformNr(interval) for interval in vechimi ]

#durataNr = [d for d in durataNr if d is not None]
miny=0.5
maxy=20

mind=0
maxd=8

scaledFeatures1 = [(feat - miny) / (maxy - miny) if feat is not None else 0 for feat in years ]
scaledFeatures2 = [(feat - 0) / 8 if feat is not None else 0 for feat in durataNr ]

plt.plot(years, durataNr, 'ro', label = 'raw data')
plt.plot(scaledFeatures1, scaledFeatures2, 'b^', label = '0-1 normalised data')
plt.legend()
plt.xlabel('experience years')
plt.ylabel('durata studii')
plt.show()

# %%
import matplotlib.pyplot as plt
from skimage import exposure, io,transform,color,feature
from skimage.feature import hog
import os
from skimage.filters import gaussian

crtDir =  os.getcwd()
filePath = os.path.join(crtDir,'Images')
images=[]
for filename in os.listdir(filePath):
    if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith(".webp"):
        path=os.path.join(filePath,filename)
        img=io.imread(path)
        images.append(img)

image=images[0]

minim=np.min(image)
maxim=np.max(image)
norm=(image-minim)/(maxim-minim)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
ax1.hist(image.flatten(), 20)
ax1.set_title('pixeli histo')
ax2.hist(norm.flatten(), 20)
ax2.set_title('[0,1] pixeli histo')
plt.show()

# %%
import nltk
import re
from unidecode import unidecode
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from collections import Counter 
import math

filePath="texts.txt"
with open(filePath, "r", encoding="utf-8") as file:
    text=file.read()

prop=nltk.sent_tokenize(text, language='english')
#LOG NORMALIZATION

for p in prop:
    cuv=nltk.word_tokenize(p.lower())
    cuv=[c for c in cuv if c.isalpha()]
    count=Counter(cuv)
    total=len(cuv)
    dict={}
    dict2={}
    for c in cuv:
        if c in dict:
            dict[c]+=1
        else:
            dict[c]=1
        
    for c in cuv:
        dict2[c]=math.log(dict[c]+1)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
    ax1.set_xticks(range(len(dict)))
    ax2.set_xticks(range(len(dict)))
    ax1.bar(dict.keys(), dict.values())
    ax1.set_xticklabels(list(dict.keys()),rotation=90)
    ax1.set_title('frecventa histo')
    ax2.bar(dict2.keys(), dict2.values())
    ax2.set_xticklabels(list(dict2.keys()),rotation=90)
    ax2.set_title('frecventa clipped histo')
    plt.show()
# Out:
# "    \nfrecv_values = [val for dict_frecv in frecv for val in dict_frecv.values()]\nfrecvlog_values = [val for dict_frecvlog in frecvlog for val in dict_frecvlog.values()]\nfor i in range(len(frecv)):\n    clipped_values=[val if val<0.05 else 0.05 for val in frecv_values]\n    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))\n    ax1.hist(frecv[i].values(), 20)\n    ax1.set_xticklabels(list(frecv[i].keys()),rotation=90)\n    ax1.set_title('frecventa histo')\n    ax2.hist(frecvlog[i].values(), 20)\n    ax2.set_xticklabels(list(frecv[i].keys()),rotation=90)\n    ax2.set_title('frecventa clipped histo')\n    plt.show()"
